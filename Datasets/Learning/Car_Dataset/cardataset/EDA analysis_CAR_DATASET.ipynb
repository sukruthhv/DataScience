# %% [markdown]
# Source :- https://www.mygreatlearning.com/blog/understanding-eda-in-python/
#
# Dataset :- Kaggle Car model dataset

# %% [markdown]
# ### Some info about the Dataset :
#
# This dataset speaks about the various Car Make/Models and their various info about the cars w.r.t Mileage / Cost (MSRP) / Vehicle type /No. of cylinders and so on.

# %% [markdown]
# I am literally following the steps mentioned in the above "Source", however googling of Pandas as how to do it?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sb

# %%
data = pd.read_csv("C:/Users/sukshe01/Desktop/INSAID/Learning/Car_Dataset/cardataset/data.csv")

# %%
data.consolidate()
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2012     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
data.tail(5)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
# Make                 11914 non-null object
# Model                11914 non-null object
# Year                 11914 non-null int64
# Engine Fuel Type     11911 non-null object
# Engine HP            11845 non-null float64
# Engine Cylinders     11884 non-null float64
# Transmission Type    11914 non-null object
# Driven_Wheels        11914 non-null object
# Number of Doors      11908 non-null float64
# Market Category      8172 non-null object
# Vehicle Size         11914 non-null object
# Vehicle Style        11914 non-null object
# highway MPG          11914 non-null int64
# city mpg             11914 non-null int64
# Popularity           11914 non-null int64
# MSRP                 11914 non-null int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %% [markdown]
# ##### The type of data will be stored as an "object" if there are strings present in the variables.

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# #### Observe the below pattern, where we rename the column names using the "{}" dictionary type. Else we would get an error.

# %%
data.rename(columns ={'Engine Fuel Type':'Fuel_Type'},inplace=True)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Fuel_Type', 'Engine HP', 'Engine Cylinders',
#        'Transmission Type', 'Driven_Wheels', 'Number of Doors',
#        'Market Category', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
data.rename(columns={'Engine HP':'HP','Engine Cylinders':'Cylinders','Transmission Type':'Transmission','Number of Doors':'Doors','Market Category':'Category','highway MPG':'h_mpg','city mpg':'c_mpg','MSRP':'Price'},inplace=True)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Fuel_Type', 'HP', 'Cylinders', 'Transmission',
#        'Driven_Wheels', 'Doors', 'Category', 'Vehicle Size', 'Vehicle Style',
#        'h_mpg', 'c_mpg', 'Popularity', 'Price'],
#       dtype='object')

# %% [markdown]
# #### As we can see below, we have drop certain columsn like "Popularity", "Doors" and "Vehicle_size"
#
# ###### Axis =0 selects the "Rows" and Axis=1 selects the "Columns"

# %%
data.drop(['Doors','Vehicle Size'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Fuel_Type', 'HP', 'Cylinders', 'Transmission',
#        'Driven_Wheels', 'Category', 'Vehicle Style', 'h_mpg', 'c_mpg',
#        'Popularity', 'Price'],
#       dtype='object')

# %%
data.drop('Category',axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 13 columns):
# Make             11914 non-null object
# Model            11914 non-null object
# Year             11914 non-null int64
# Fuel_Type        11911 non-null object
# HP               11845 non-null float64
# Cylinders        11884 non-null float64
# Transmission     11914 non-null object
# Driven_Wheels    11914 non-null object
# Vehicle Style    11914 non-null object
# h_mpg            11914 non-null int64
# c_mpg            11914 non-null int64
# Popularity       11914 non-null int64
# Price            11914 non-null int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.2+ MB

# %%
data.isnull().sum()
# Out:
# Make              0
# Model             0
# Year              0
# Fuel_Type         3
# HP               69
# Cylinders        30
# Transmission      0
# Driven_Wheels     0
# Vehicle Style     0
# h_mpg             0
# c_mpg             0
# Popularity        0
# Price             0
# dtype: int64

# %% [markdown]
# We are doing Mean just to know teh % of teh values being missed and multiply by 100 to get the percentage. As we could see below that the % is very small, so we can drop as mentioned in the document. "dropna" is the function to drop any rows with NA/Blanks/NaN

# %%
data.isnull().mean()*100
# Out:
# Make             0.000000
# Model            0.000000
# Year             0.000000
# Fuel_Type        0.025180
# HP               0.579151
# Cylinders        0.251805
# Transmission     0.000000
# Driven_Wheels    0.000000
# Vehicle Style    0.000000
# h_mpg            0.000000
# c_mpg            0.000000
# Popularity       0.000000
# Price            0.000000
# dtype: float64

# %%
data.dropna(inplace=True)

# %% [markdown]
# After dropping the missing values rows, we could see that there are equal no. of rows in each of the 12 columns!!

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11813 entries, 0 to 11913
# Data columns (total 13 columns):
# Make             11813 non-null object
# Model            11813 non-null object
# Year             11813 non-null int64
# Fuel_Type        11813 non-null object
# HP               11813 non-null float64
# Cylinders        11813 non-null float64
# Transmission     11813 non-null object
# Driven_Wheels    11813 non-null object
# Vehicle Style    11813 non-null object
# h_mpg            11813 non-null int64
# c_mpg            11813 non-null int64
# Popularity       11813 non-null int64
# Price            11813 non-null int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.3+ MB

# %%
data.isnull().sum()
# Out:
# Make             0
# Model            0
# Year             0
# Fuel_Type        0
# HP               0
# Cylinders        0
# Transmission     0
# Driven_Wheels    0
# Vehicle Style    0
# h_mpg            0
# c_mpg            0
# Popularity       0
# Price            0
# dtype: int64

# %%
data.describe()
data.describe(include="all")
# Out:
#              Make           Model          Year         Fuel_Type  \
# count       11813           11813  11813.000000             11813
# unique         47             904           NaN                 9
# top     Chevrolet  Silverado 1500           NaN  regular unleaded
# freq         1115             156           NaN              7155
# mean          NaN             NaN   2010.361805               NaN
# std           NaN             NaN      7.594364               NaN
# min           NaN             NaN   1990.000000               NaN
# 25%           NaN             NaN   2007.000000               NaN
# 50%           NaN             NaN   2015.000000               NaN
# 75%           NaN             NaN   2016.000000               NaN
# max           NaN             NaN   2017.000000               NaN
#
#                   HP     Cylinders Transmission      Driven_Wheels  \
# count   11813.000000  11813.000000        11813              11813
# ...

# %% [markdown]
# From the above descriptive stats, we could derive the following :
# 1. There are 47 Unique Make and 904 Unique Models
# 2. Out of all these cars, there are highest (1115) no. of Chevrolet cars
# 3. The avergae prive is around 40,581 dollars and the Median(50-Percentile) is around 29,970 dollars - <b> Which indicates that this is positively skewed </b> -- Checkout the INSAID stats one note to find the skewness

# %%
from scipy.stats import norm
mp.hist(data['HP'],bins=60,color="blue")
mp.plot(data['HP'],norm.pdf(data['HP']),color='red')
mp.plot?
#norm.pdf?
#mp.plot(pdf)
mp.show()
data['HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
# 5        230.0
# 6        300.0
# 7        300.0
# 8        230.0
# 9        230.0
# 10       300.0
# 11       230.0
# 12       300.0
# 13       230.0
# 14       230.0
# 15       320.0
# 16       320.0
# 17       172.0
# 18       172.0
# 19       172.0
# 20       172.0
# 21       172.0
# 22       172.0
# 23       172.0
# 24       172.0
# 25       172.0
# 26       172.0
# 27       172.0
# 28       172.0
# 29       172.0
#          ...
# 11884    225.0
# 11885    184.0
# 11886    225.0
# 11887    225.0
# 11888    184.0
# 11889    225.0
# 11890    330.0
# 11891    330.0
# 11892    330.0
# 11893    330.0
# 11894    240.0
# 11895    300.0
# 11896    335.0
# 11897    240.0
# 11898    300.0
# 11899    335.0
# 11900    300.0
# 11901    240.0
# 11902    335.0
# 11903    394.0
# 11904    394.0
# 11905    394.0
# 11906    300.0
# 11907    300.0
# 11908    300.0
# 11909    300.0
# 11910    300.0
# ...
