# %% [markdown]
# <img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="360" />
#
# # ASSIGNMENT
# # LOGISTIC REGRESSION

# %% [markdown]
# ##  Bank Marketing
#
#
# **Abstract:**
# The data is related with __direct marketing campaigns__ (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a __term deposit (variable y)__.
#
# **Data Set Information:**
# The data is related with direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the __product (bank term deposit)__ would be __('yes')__ or __('no')__ subscribed.
#
# ###  Source:
#
#  - Dataset from : http://archive.ics.uci.edu/ml/datasets/Bank+Marketing#

# %% [markdown]
# ### Import the dataset

# %%
import pandas as pd
bank = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-2/master/Data/bank.csv')
bank.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   46  blue-collar  married           basic.9y       no      no  yes
# 1   29       admin.   single  university.degree       no      no   no
# 2   50   management  married  university.degree       no     yes  yes
# 3   31       admin.  married        high.school  unknown     yes   no
# 4   32       admin.   single        high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         tue  ...         3    999         0  nonexistent
# 1   cellular   may         wed  ...         2    999         0  nonexistent
# 2   cellular   apr         fri  ...         1    999         0  nonexistent
# 3  telephone   may         thu  ...         2    999         0  nonexistent
# 4   cellular   jun         tue  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 0          1.1          93.994          -36.4      4.857       5191.0   no
# 1         -1.8          92.893          -46.2      1.281       5099.1   no
# 2         -1.8          93.075          -47.1      1.405       5099.1   no
# 3          1.1          93.994          -36.4      4.860       5191.0   no
# 4         -2.9          92.963          -40.8      1.262       5076.2  yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Check the columns present in the dataset

# %%
bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# ### Check the shape of Dataset

# %%
bank.shape
# Out:
# (10297, 21)

# %% [markdown]
# ### Check the descriptive statistics of the dataset

# %%
bank.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  10297.000000  10297.000000  10297.000000  10297.000000  10297.000000
# mean      40.080606    261.388268      2.561134    963.609692      0.171506
# std       10.472190    263.722874      2.827084    184.098592      0.496992
# min       18.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    103.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    327.000000      3.000000    999.000000      0.000000
# max       94.000000   3643.000000     56.000000    999.000000      6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  10297.000000    10297.000000   10297.000000  10297.000000  10297.000000
# mean       0.077256       93.574206     -40.445780      3.621923   5166.850442
# std        1.576732        0.577502       4.622221      1.734170     72.492914
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Check the info of the dataset

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10297 entries, 0 to 10296
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             10297 non-null  int64
#  1   job             10297 non-null  object
#  2   marital         10297 non-null  object
#  3   education       10297 non-null  object
#  4   default         10297 non-null  object
#  5   housing         10297 non-null  object
#  6   loan            10297 non-null  object
#  7   contact         10297 non-null  object
#  8   month           10297 non-null  object
#  9   day_of_week     10297 non-null  object
#  10  duration        10297 non-null  int64
#  11  campaign        10297 non-null  int64
#  12  pdays           10297 non-null  int64
#  13  previous        10297 non-null  int64
#  14  poutcome        10297 non-null  object
#  15  emp.var.rate    10297 non-null  float64
#  16  cons.price.idx  10297 non-null  float64
#  17  cons.conf.idx   10297 non-null  float64
#  18  euribor3m       10297 non-null  float64
#  19  nr.employed     10297 non-null  float64
#  20  y               10297 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Q 1. Write a code to understand the below mentioned variables and print their 'unique' attributes.
# ``` ['job', 'marital', 'education', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'campaign','poutcome', 'pdays', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m'] ```

# %%
def log():
    # write your code here to print all the unique values of the variables mentioned in question.
    # The code output should be user-friendly.
    # For eg- Job have these unique values: ['.........']
    attributes=['job', 'marital', 'education', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'campaign','poutcome', 'pdays', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m']
    for var in attributes:
        print("{0} has the following unique attributes: \n{1}\n".format(var,bank[var].value_counts()))
        
log()
# Out:
# job has the following unique attributes:
# admin.           2608
# blue-collar      2258
# technician       1707
# services          977
# management        752
# retired           462
# entrepreneur      366
# self-employed     355
# housemaid         266
# unemployed        244
# student           225
# unknown            77
# Name: job, dtype: int64
#
# marital has the following unique attributes:
# married     6293
# single      2853
# divorced    1128
# unknown       23
# Name: marital, dtype: int64
#
# education has the following unique attributes:
# university.degree      3034
# high.school            2393
# basic.9y               1502
# professional.course    1347
# basic.4y               1028
# basic.6y                582
# unknown                 405
# illiterate                6
# Name: education, dtype: int64
#
# housing has the following unique attributes:
# yes        5418
# no         4619
# unknown     260
# Name: housing, dtype: int64
#
# loan has the following unique attributes:
# no         8486
# yes        1551
# unknown     260
# Name: loan, dtype: int64
#
# contact has the following unique attributes:
# cellular     6549
# telephone    3748
# Name: contact, dtype: int64
#
# month has the following unique attributes:
# may    3406
# jul    1786
# aug    1539
# jun    1340
# nov    1048
# apr     654
# oct     176
# sep     159
# mar     140
# dec      49
# Name: month, dtype: int64
#
# day_of_week has the following unique attributes:
# thu    2160
# mon    2114
# wed    2088
# tue    2000
# fri    1935
# Name: day_of_week, dtype: int64
#
# campaign has the following unique attributes:
# 1     4442
# 2     2659
# 3     1348
# 4      626
# 5      390
# 6      246
# 7      142
# 8       89
# 9       67
# 10      63
# 11      36
# 13      32
# 12      30
# 14      22
# 16      14
# 15      12
# 17      11
# 20       9
# 18       9
# 19       7
# 21       6
# 23       6
# 27       5
# 22       5
# 29       3
# 24       3
# 26       3
# 28       3
# 33       2
# 25       1
# 56       1
# 40       1
# 32       1
# 34       1
# 31       1
# 39       1
# Name: campaign, dtype: int64
#
# poutcome has the following unique attributes:
# nonexistent    8905
# failure        1064
# success         328
# Name: poutcome, dtype: int64
#
# pdays has the following unique attributes:
# 999    9930
# 3       108
# 6        95
# 4        29
# 9        18
# 12       17
# 5        15
# 2        15
# 13       11
# 7         9
# 11        8
# 1         7
# 15        6
# 14        6
# 10        6
# 8         5
# 16        3
# 0         3
# 17        3
# 18        1
# 20        1
# 26        1
# Name: pdays, dtype: int64
#
# emp.var.rate has the following unique attributes:
#  1.4    4036
# -1.8    2246
#  1.1    1954
# -0.1     944
# -2.9     427
# -3.4     285
# -1.7     202
# -1.1     154
# -3.0      49
# Name: emp.var.rate, dtype: int64
#
# cons.price.idx has the following unique attributes:
# 93.994    1954
# 93.918    1663
# 92.893    1404
# 93.444    1294
# 94.465    1079
# 93.200     929
# 93.075     611
# 92.963     200
# 92.201     189
# 92.431     110
# 92.649      94
# 94.215      85
# 92.379      81
# 94.199      78
# 93.369      70
# 92.843      70
# 94.055      61
# 94.027      56
# 94.601      51
# 92.713      49
# 93.876      48
# 93.749      43
# 92.469      38
# 94.767      25
# 93.798      15
# Name: cons.price.idx, dtype: int64
#
# cons.conf.idx has the following unique attributes:
# -36.4    1954
# -42.7    1663
# -46.2    1404
# -36.1    1294
# -41.8    1079
# -42.0     929
# -47.1     611
# -40.8     200
# -31.4     189
# -26.9     110
# -30.1      94
# -40.3      85
# -29.8      81
# -37.5      78
# -50.0      70
# -34.8      70
# -39.8      61
# -38.3      56
# -49.5      51
# -33.0      49
# -40.0      48
# -34.6      43
# -33.6      38
# -50.8      25
# -40.4      15
# Name: cons.conf.idx, dtype: int64
#
# euribor3m has the following unique attributes:
# 4.857    719
# 4.963    637
# 4.962    628
# 4.961    471
# 4.856    306
#         ...
# 5.045      1
# 1.049      1
# 3.853      1
# 4.663      1
# 3.901      1
# Name: euribor3m, Length: 282, dtype: int64

# %% [markdown]
# ### Q 2. Write a code to check the min and max value of age. Also check if there is any null value or not.

# %%
def log():
    # print the max age
    # print the min age
    # print the missing values if any
    print("Min age is ",bank['age'].min())
    print("Max age is ",bank['age'].max())
    print("Are there any NULL values?",bank['age'].isnull().sum())
log()
# Out:
# Min age is  18
# Max age is  94
# Are there any NULL values? 0

# %% [markdown]
# ### Count of Yes and No for the term deposit

# %%
bank.y.value_counts()
# Out:
# no     9137
# yes    1160
# Name: y, dtype: int64

# %% [markdown]
# ### Q 3. Write a user defined function to calculate the Inter quartile range for quantile values outside 25 to 75 range. And do the outlier capping for lower level with min value and for upper level with 'q3=1.5*iqr' value.

# %%
import numpy as np
def remove_outlier(df_in, col_name):
    # Calculate quantile 1 using quantile(0.25)
    # Calculate quantile 3
    # Calculate IQR as difference of Quantile 3 and quantile 1
    # Find the lower bound using the min() function
    # Find the upper bound as quantile3 + 1.5*IQR
    # Print the lower and upper bound of the column
    # Remove the values lying outside min and upper bound range
    q1_25=np.quantile(df_in[col_name],0.25)
    q2_50=np.quantile(df_in[col_name],0.5)
    q3_75=np.quantile(df_in[col_name],0.75)
    iqr = q3_75 - q1_25
    l_bound=df_in[col_name].min()
    u_bound=q3_75 + (1.5*iqr) 
    print("Lower bound = {0} ; Upper bound = {1}".format(l_bound,u_bound))
    df_out=df_in.loc[(df_in[col_name]>l_bound) & (df_in[col_name]<u_bound)]
    return df_out

# %% [markdown]
# ### Q 3.1 Using the above created function , remove the outlier from 'age' variables:

# %%
def log(bank):
    # your code to remove the outlier from age
    return(remove_outlier(bank,"age"))
bank = log(bank) 
sns.boxplot(data=bank['age'])
# Out:
# Lower bound = 18 ; Upper bound = 69.5

# %% [markdown]
# ### Q 3.2 Using the above created function , remove the outlier from 'campaign' variables:

# %%
def log(bank):
    # your code to remove the outlier from campaign
    return(remove_outlier(bank,"campaign"))
bank = log(bank)
sns.boxplot(bank['campaign'])
# Out:
# Lower bound = 1 ; Upper bound = 6.0

# %% [markdown]
# ### Q 3.3 Using the above created function , remove the outlier from 'duration' variables:

# %%
def log(bank):
    # your code to remove the outlier from duration
    return(remove_outlier(bank,"duration"))
bank = log(bank)
# Out:
# Lower bound = 0 ; Upper bound = 684.0

# %% [markdown]
# ### Dividing dataset into two, on the basis of categorical and numerical.

# %%
bank_cat=bank[['job', 'marital','default', 'education', 'loan', 'housing', 'contact', 'month', 'day_of_week', 'poutcome', 'y']]

# %%
bank_cont = bank.drop(['job', 'marital','default', 'education', 'loan', 'housing', 'contact', 'month', 'day_of_week', 'poutcome', 'y'], axis=1)

# %% [markdown]
# ### Q 4. Label encode the below mentioned categorical variable to numerical values.
# ``` ['job', 'marital','default','education', 'loan', 'housing', 'contact', 'month', 'day_of_week', 'poutcome', 'y'] ```

# %%
from sklearn.preprocessing import LabelEncoder
def log(bank_cat):
    # your code to return the value applying fit_transorm
    return(bank_cat.apply(LabelEncoder().fit_transform))
bank_cat = log(bank_cat)
bank_cat
# Out:
#        job  marital  default  education  loan  housing  contact  month  \
# 0        1        1        0          2     2        0        1      6
# 1        0        2        0          6     0        0        0      6
# 3        0        1        1          3     0        2        1      6
# 5        0        2        0          6     2        2        0      1
# 8        1        1        1          5     0        0        0      6
# ...    ...      ...      ...        ...   ...      ...      ...    ...
# 10289    9        1        0          5     2        2        0      0
# 10290   10        1        1          6     1        1        1      6
# 10291    9        1        0          3     0        0        1      4
# 10294    1        1        1          5     0        2        0      7
# 10295    9        1        0          6     0        2        1      6
#
#        day_of_week  poutcome  y
# 0                3         1  0
# 1                4         1  0
# 3                2         1  0
# 5                1         1  0
# 8                4         0  0
# ...            ...       ... ..
# 10289            2         2  1
# 10290            3         1  0
# 10291            2         1  0
# 10294            4         0  0
# 10295            2         1  0
#
# [4621 rows x 11 columns]

# %% [markdown]
# ### Combining the numerical and categorical dataset.

# %%
bank_final= pd.concat([bank_cont, bank_cat], axis = 1)

# %% [markdown]
# ### Q 6. Extract independent column to prepare X

# %%
X = pd.DataFrame()
def log():
    # write your code to create a dataframe of dependent variables excluding 'y' variable
    X=bank_final.loc[:,bank.columns!='y']
    return X
X = log()
X
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       46       329         3    999         0           1.1          93.994
# 1       29       132         2    999         0          -1.8          92.893
# 3       31       199         2    999         0           1.1          93.994
# 5       33       174         4    999         0           1.4          93.444
# 8       34        65         2    999         1          -1.8          92.893
# ...    ...       ...       ...    ...       ...           ...             ...
# 10289   36       266         2      2         2          -1.8          93.075
# 10290   43        87         2    999         0           1.1          93.994
# 10291   58       246         3    999         0           1.4          94.465
# 10294   52       442         2    999         1          -0.1          93.200
# 10295   35       330         3    999         0           1.1          93.994
#
#        cons.conf.idx  euribor3m  nr.employed  job  marital  default  \
# 0              -36.4      4.857       5191.0    1        1        0
# 1              -46.2      1.281       5099.1    0        2        0
# 3              -36.4      4.860       5191.0    0        1        1
# 5              -36.1      4.963       5228.1    0        2        0
# 8              -46.2      1.281       5099.1    1        1        1
# ...              ...        ...          ...  ...      ...      ...
# 10289          -47.1      1.365       5099.1    9        1        0
# 10290          -36.4      4.857       5191.0   10        1        1
# 10291          -41.8      4.961       5228.1    9        1        0
# 10294          -42.0      4.120       5195.8    1        1        1
# 10295          -36.4      4.855       5191.0    9        1        0
#
#        education  loan  housing  contact  month  day_of_week  poutcome
# 0              2     2        0        1      6            3         1
# 1              6     0        0        0      6            4         1
# 3              3     0        2        1      6            2         1
# 5              6     2        2        0      1            1         1
# 8              5     0        0        0      6            4         0
# ...          ...   ...      ...      ...    ...          ...       ...
# 10289          5     2        2        0      0            2         2
# 10290          6     1        1        1      6            3         1
# 10291          3     0        0        1      4            2         1
# 10294          5     0        2        0      7            4         0
# 10295          6     0        2        1      6            2         1
#
# [4621 rows x 20 columns]

# %% [markdown]
# ### Q 7. Extract dependent variable into a dataframe 'y' for model predcition

# %%
y = pd.DataFrame()
def log():
    # write your code to create a dataframe which consists only of dependepent variable
    y=bank_final['y']
    return y
y = log()
y
# Out:
# 0        0
# 1        0
# 3        0
# 5        0
# 8        0
#         ..
# 10289    1
# 10290    0
# 10291    0
# 10294    0
# 10295    0
# Name: y, Length: 4621, dtype: int64

# %% [markdown]
# ### Q 8. Splitting X and y intro train and test dataset

# %%
from sklearn.model_selection import train_test_split
def log():
    return (train_test_split(X,y,test_size=0.25,random_state=1)) # train test split using train_test_split of 75:25 and random state=1
X_train, X_test, y_train, y_test = log()

# %% [markdown]
# ### Check the shape of X an y of train dataset.

# %%
def log():
    print(X_train.shape)
    print(y_train.shape)
log()
# Out:
# (3465, 20)
# (3465,)

# %% [markdown]
# ### Check the shape of X and y of test dataset.

# %%
def log():
    print(X_test.shape)
    print(y_test.shape)
log()
# Out:
# (1156, 20)
# (1156,)

# %% [markdown]
# ### Q 9. Instantitate Logistic Regression model using scikit-learn

# %%
from sklearn.linear_model import LogisticRegression
def log():
    # initiate the logistic regression model to new variable logreg
    logreg=LogisticRegression()
    return logreg
logreg = log()

# %% [markdown]
# ### Q 10. Fit the logistic model on X_train and y_train

# %%
def log():
    # fit the X_train and y_train
    # We don't expect any return from your side.
    logreg.fit(X_train,y_train)
log()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# ### Q 11. Using the model for prediction

# %%
y_pred_train = pd.DataFrame()
def log():
    # create the model prediction on X_train data using the above created dataframe
    y_pred_train=logreg.predict(X_train)
    return y_pred_train
y_pred_train = log()

# %%
y_pred_test = pd.DataFrame()
def log():
    # create the model prediction on X_test data using the above created dataframe
    y_pred_test=logreg.predict(X_test)
    return y_pred_test
y_pred_test = log()

# %% [markdown]
# ### Q 12. Model evaluation using accuracy classification score

# %%
from sklearn.metrics import accuracy_score
def log():
    #Calculate and print the accuracy score
    print(accuracy_score(y_train,y_pred_train))
    print(accuracy_score(y_test,y_pred_test))
log()
# Out:
# 0.9385281385281385
# 0.9411764705882353

# %% [markdown]
# ### Q 13. Model evaluation using Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(y_test, y_pred_test))
def log():
    # provide confusion matrix index name as['Actual No_Deposit','Actual Deposit']
    # provide confusion matrix index name as['Predicted No_Deposit','Predicted Deposit']
    confusion_matrix.index=['Loan_Not_taken_Actual','Loan_Taken_Actual']
    confusion_matrix.columns=['Loan_Not_taken_Predicted','Loan_Taken_Predicted']
    print(confusion_matrix)
log()
# Out:
#                        Loan_Not_taken_Predicted  Loan_Taken_Predicted
# Loan_Not_taken_Actual                      1063                    13
# Loan_Taken_Actual                            55                    25

# %% [markdown]
# ### Q 14. Accuracy prediction setting the threshold = 0.75

# %%
X_test
# Out:
#       age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 1953   37       194         3    999         0           1.4          93.444
# 440    48       427         3    999         0           1.1          93.994
# 9597   48       461         2    999         0           1.4          94.465
# 9817   37        90         4    999         0           1.4          94.465
# 7430   45        99         2    999         0           1.4          93.444
# ...   ...       ...       ...    ...       ...           ...             ...
# 2847   38        85         5    999         0           1.4          93.444
# 7995   51       178         2    999         1          -0.1          93.200
# 7447   49       163         2    999         0           1.4          94.465
# 3975   52       111         3    999         0           1.4          94.465
# 5012   50        98         2    999         0           1.4          93.918
#
#       cons.conf.idx  euribor3m  nr.employed  job  marital  default  education  \
# 1953          -36.1      4.964       5228.1    9        2        0          6
# 440           -36.4      4.859       5191.0    0        0        0          5
# 9597          -41.8      4.961       5228.1    6        1        1          2
# 9817          -41.8      4.961       5228.1    1        1        0          3
# 7430          -36.1      4.965       5228.1    1        1        0          2
# ...             ...        ...          ...  ...      ...      ...        ...
# 2847          -36.1      4.965       5228.1    0        1        0          6
# 7995          -42.0      4.191       5195.8    1        1        0          0
# 7447          -41.8      4.961       5228.1    4        0        0          6
# 3975          -41.8      4.960       5228.1    5        0        0          0
# 5012          -42.7      4.961       5228.1    4        1        0          6
#
#       loan  housing  contact  month  day_of_week  poutcome
# 1953     0        2        0      1            4         1
# 440      0        2        1      6            0         1
# 9597     0        2        1      4            2         1
# 9817     0        2        1      4            1         1
# 7430     0        2        0      1            1         1
# ...    ...      ...      ...    ...          ...       ...
# 2847     0        0        0      1            3         1
# 7995     2        2        0      7            1         0
# 7447     0        0        1      4            2         1
# 3975     0        2        1      4            1         1
# 5012     0        2        0      3            3         1
#
# [1156 rows x 20 columns]

# %%
import numpy as np
def log():
    # Calculate preds1 keeping the probabilty value as 0.75
    # calculate and print the accuracy using the above mentioned threshold probability
    preds1=np.where(logreg.predict_proba(X_test)[:,1]>0.75,1,0)
    display(preds1)
    print(accuracy_score(y_test,preds1))
log()
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
# 0.9420415224913494

# %% [markdown]
# ### Q 15. Accuracy prediction setting the threshold = 0.25

# %%
def log():
    # Calculate preds2 keeping the probabilty value as 0.25
    # calculate and print the accuracy using the above mentioned threshold probability
    preds2=np.where(logreg.predict_proba(X_test)[:,1]>0.25,1,0)
    print(accuracy_score(y_test,preds2))
log()
# Out:
# 0.9273356401384083
